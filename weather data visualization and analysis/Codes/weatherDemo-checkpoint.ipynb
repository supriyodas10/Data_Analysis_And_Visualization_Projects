# %%
#Step 1 : Importing libraries like Numpy, Pandas, Matplotlib, Seaborn and scikit learn(Sklearn)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
sns.set(color_codes=True)

# %%
#Step2 : Load the Dataset
weather = pd.read_csv(r'C:\Users\supriyo das\OneDrive\Desktop\da projects\weather analysis\Test.csv')

# %%
# Display first five records of data
weather.head()

# %%
# Display last five records of the data
weather.tail()

# %%
# Display randomly any number of records of data
weather.sample(10)

# %%
#Number of rows and columns
weather.shape

# %%
 #List the types of all columns.
weather.dtypes

# %%
#finding out if the dataset contains any null value
weather.info()

# %%
# Statistical summary
weather.describe()

# %%
# check the shape before drop the duplicates
weather.shape

# %%
#drop duplicates
weather=weather.drop_duplicates()

# %%
# check the shape after drop the duplicates
weather.shape

# %%
# Count of null, values
# check the missing values in any column
# Display number of null values in every column in dataset
pd.isnull(weather)

# %%
# Count of null, values
# check the missing values in any column
# Display number of null values in every column in dataset
pd.isnull(weather).sum()

# %%
sns.barplot(x= weather.humidity, y=weather.temperature, hue=weather.humidity )

# %%
sns.distplot(x=weather.humidity, kde=False, rug=True);

# %%
sns.jointplot(x=weather.humidity, y=weather.temperature)

# %%
sns.jointplot(x=weather.humidity, y=weather.temperature, kind="hex")

# %%
sns.jointplot(x=weather.humidity, y=weather.temperature, kind="kde")

# %%
sns.pairplot(weather[['humidity', 'temperature', 'air_pollution_index']])

# %%
sns.stripplot(x=weather.weather_type, y=weather.temperature,hue= weather.weather_type, linewidth=0.6)

# %%
sns.boxplot(x=weather.humidity, y=weather.temperature, hue=weather.weather_type)

# %%
sns.barplot(x=weather.humidity,y= weather.temperature, hue=weather.weather_type)

# %%
sns.countplot(x=weather.weather_type, hue= weather.weather_type, linewidth=1, edgecolor='black')

# %%
sns.pointplot(x=weather.humidity,y= weather.temperature, hue=weather.weather_type)

# %%
sns.lmplot(x="humidity", y="temperature", data=weather)

# %%
sns.lmplot(x="humidity", y="temperature", hue="weather_type", data=weather)

# %%
sns.boxplot(x =weather.temperature)
plt.show()

# %%
sns.kdeplot(weather['temperature'])
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(x = weather.temperature, y = weather.humidity, label = 'Camparision of temperature and humidity')
plt.scatter(x = weather.temperature, y = weather.air_pollution_index, label = 'Camparision of temperature and air pollution index')
plt.legend()
plt.show()

# %%
#Histograms
#Histograms are one of the most common graphs used to display numeric data.
#distribution of the data - Whether the data is normally distributed or if it’s skewed (to the left or right)

weather.hist(bins=10,figsize=(10,10))
plt.show()

# %%
#Scatter plot
#Scatterplots are useful for many reasons: like correlation matrices, it allows us to quickly understand a relationship between two variables.
sns.pairplot(weather,  hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='auto', markers=None, height=2.5, aspect=1, corner=False, dropna=False, plot_kws=None, diag_kws=None, grid_kws=None, size=None)
